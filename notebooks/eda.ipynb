# %%
import sys , os
sys.path.append(os.path.abspath('../scripts'))

# %%
import collection_and_cleaning as cac

# %% [markdown]
# # Defning the stock tickers

# %%
tickers = ['TSLA', 'BND', 'SPY']

# %% [markdown]
# # Data Extraction

# %%
data = cac.data_extraction(tickers)
# Out:
# INFO:collection_and_cleaning:extracting the data using yfinance by tickers
# INFO:collection_and_cleaning:extracting data
# [*********************100%***********************]  3 of 3 completed
# INFO:collection_and_cleaning:extraction finished succesfully

# %%
data.head()
# Out:
# Ticker                           BND         SPY       TSLA
# Date
# 2018-01-02 00:00:00+00:00  67.510849  240.801529  21.368668
# 2018-01-03 00:00:00+00:00  67.568970  242.324631  21.150000
# 2018-01-04 00:00:00+00:00  67.535774  243.345932  20.974667
# 2018-01-05 00:00:00+00:00  67.444473  244.967606  21.105333
# 2018-01-08 00:00:00+00:00  67.452797  245.415665  22.427334

# %% [markdown]
# # Data Cleanig And Understanding

# %%
cac.data_cleaning_and_uderstanding(data)
# Out:
# INFO:collection_and_cleaning:data cleaning and understanding
# INFO:collection_and_cleaning:the null values of the data
# INFO:collection_and_cleaning:if any missing value is identified they will be filled
# c:\Users\bekib\Desktop\10ACADAMY\WEEK-ELEVEN\week-11\scripts\collection_and_cleaning.py:27: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df.fillna(method='ffill', inplace=True)
# INFO:collection_and_cleaning:basic statistics calculating the summary statistics
# Ticker
# BND     0
# SPY     0
# TSLA    0
# dtype: int64
# Ticker          BND          SPY         TSLA
# count   1259.000000  1259.000000  1259.000000
# mean      72.865596   323.572549   131.784972
# std        4.780602    69.468301   117.835854
# min       64.981987   208.617615    11.931333
# 25%       68.000332   259.868729    21.078333
# 50%       73.423119   305.455017    80.577332
# ...

# %% [markdown]
# # Exploratory Data Analysis

# %%
cac.exploratory_data_analysis(data)
# Out:
# INFO:collection_and_cleaning:exploratory Data Analysis (EDA)
# INFO:collection_and_cleaning:Visualization of the Closing Price
# INFO:collection_and_cleaning:plot the Daily Percentage Change and Volatility
# INFO:collection_and_cleaning:calculating the daily returns
# INFO:collection_and_cleaning:plot daily returns
# INFO:collection_and_cleaning:Rolling Means and Standard Deviations
# INFO:collection_and_cleaning:cacluating rolling mean and std
# INFO:collection_and_cleaning:plot rolling mean and std

# %% [markdown]
# # Outlier Detection and Analysis

# %%
cac.outlier_detection_and_anaylis(data)
# Out:
# INFO:collection_and_cleaning:outlier detection and Analysis
# INFO:collection_and_cleaning:outlier Detection
# outliers in daily returns
# Ticker                     BND  SPY  TSLA
# Date
# 2018-01-03 00:00:00+00:00  NaN  NaN   NaN
# 2018-01-04 00:00:00+00:00  NaN  NaN   NaN
# 2018-01-05 00:00:00+00:00  NaN  NaN   NaN
# 2018-01-08 00:00:00+00:00  NaN  NaN   NaN
# 2018-01-09 00:00:00+00:00  NaN  NaN   NaN
# ...                        ...  ...   ...
# 2022-12-23 00:00:00+00:00  NaN  NaN   NaN
# 2022-12-27 00:00:00+00:00  NaN  NaN   NaN
# 2022-12-28 00:00:00+00:00  NaN  NaN   NaN
# 2022-12-29 00:00:00+00:00  NaN  NaN   NaN
# 2022-12-30 00:00:00+00:00  NaN  NaN   NaN
#
# [1258 rows x 3 columns]

# %% [markdown]
# # Seasonality and Trends

# %%
cac.seasonality_and_trends(data)
# Out:
# INFO:collection_and_cleaning:seasonality and trends Analysis
# INFO:collection_and_cleaning:Breaking Down the time series into trend , Seasonlaity and residuals for deeper insights

# %% [markdown]
# # Risk and Performance Metrics

# %%
cac.risk_and_performance_metrics(data)
# Out:
# INFO:collection_and_cleaning:Risk and Performance Metrics
# INFO:collection_and_cleaning:calculate VaR to estimate potential losses in adverse scenarios i calcucalte aR at 95% confidence level
# INFO:collection_and_cleaning:calcualting the Sharoe Ratio as a measure if risk-adjsuted returns
# Value ata Risk (95% confidence):
# Ticker
# BND    -0.005019
# SPY    -0.021258
# TSLA   -0.063759
# Name: 0.05, dtype: float64
# sharpe ratio
# Ticker
# BND     0.042239
# SPY     0.515573
# TSLA    0.862401
# dtype: float64

# %%
data.to_csv('../data/dataset.csv' ,index=False )

# %%
data.shape
# Out:
# (1259, 3)
